# %% [markdown]
# <a href="https://colab.research.google.com/github/pasumarthi/EVA/blob/master/Session13/Assignment13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EVA Session13 Assignment 13:
#
# Objective:
#
# To train the network incorporating the following rules:
#
# 1. Refer to your EVA S12 Assignment 12.
# 2. Replace whatever model you have there with the ResNet18 model as shown below.
# 3. Your model must look like Conv->B1->B2->B3->B4 and not individually called Convs.
# 4. If not already using, then:
#  * Use Batch Size 128
#  * Use Normalization values of: (0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)
#  * Random Crop of 32 with padding of 4px
#  * Horizontal Flip (0.5)
#  * Optimizer: SGD, Weight-Decay: 5e-4
#  * OneCycleLR
# 5. Save model (to drive) after every 50 epochs or best model till now
# 6. Describe your blocks, and the stride strategy you have picked
# 7. Train for 300 Epochs
# 8. Assignment Target Accuracy is 90%, so exit gracefully if you reach 90% (you can target more, it can go till ~93%)

# %% [markdown]
# # # 1. Import APIs and library

# %%
import time
import math
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(11082019) 
from keras.models import Sequential, Model, load_model
from keras.layers.convolutional import MaxPooling2D, SeparableConv2D, Convolution2D, Conv2D, AveragePooling2D
from keras.layers import Activation, Flatten, Dropout, Input, Lambda, add, ZeroPadding2D
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras import regularizers
from keras import backend as K

from keras.optimizers import SGD
from keras.callbacks import LearningRateScheduler
from keras.layers.advanced_activations import ReLU
import tensorflow as tf
from keras.layers.merge import concatenate

import cv2
from keras.preprocessing import image
from google.colab.patches import cv2_imshow

import matplotlib.gridspec as gridspec

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# # # 2. Define helper functions
#
#
# 1.   get_cifar10_data
# 2.   get_cifar10_labels
# 3.   show_examples
# 4.   plot_model_history
# 5.   get_cutout_eraser (Random Crop of 32 with padding of 4px)

# %%
def get_cifar10_data():
    from keras.datasets import cifar10
    (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
    num_train, img_channels, img_rows, img_cols =  train_features.shape
    num_test, _, _, _ =  test_features.shape
    num_classes = len(np.unique(train_labels))

    # Flatten 32x32x3 images to a 1024*3 vector for each image.
    train_features = train_features.reshape(train_features.shape[0], 32, 32, 3)
    test_features = test_features.reshape(test_features.shape[0], 32, 32, 3)

    train_features = train_features.astype('float32')/255
    test_features = test_features.astype('float32')/255

    # convert class labels to binary class labels
    train_labels = np_utils.to_categorical(train_labels, num_classes)
    test_labels = np_utils.to_categorical(test_labels, num_classes)
    return (train_features, train_labels), (test_features, test_labels)

def get_cifar10_labels():
    class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
    return class_names

def show_examples(X,y,classes):
    rows = int(np.ceil(len(X)/5))
    if X.shape[1] > 64:
        multiplier = 2
    else:
        multiplier = 1
    fig = plt.figure(figsize=(10*multiplier, rows*2*multiplier))
    for idx in np.arange(len(X)):
        img = X[idx]
        assert (len(img.shape)==3 and img.shape[2] in [1,3,4]) or len(img.shape)==2
        ax = fig.add_subplot(rows, 5, idx + 1, xticks=[], yticks=[])
        cmap = None
        if (len(img.shape)==3 and img.shape[2]==1) or len(img.shape)==2:
            cmap="binary"
        if len(img.shape)==3 and img.shape[2]==1:
            img = img.reshape((img.shape[0],img.shape[1]))
        ax.imshow(img,cmap=cmap)
        ax.set_title(classes[np.argmax(y[idx])])
    plt.show()
        
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()    
        
# Cut-out
def get_cutout_eraser(p=0.5, s_l=0.05, s_h=0.3, r_1=0.3, r_2=1 / 0.3, max_erasures_per_image=1, random_crop_size=(32, 32), padding_for_crop=4, pixel_level=True):
  
    """
    :param p:
    :param s_l: Minimum Area Proportion of Original that may be cut
    :param s_h: Maximum Area Proportion of Original that may be cut
    :param r_1: Min Aspect Ratio
    :param r_2: Max Aspect Ratio
    :param max_erasures_per_image:
    :param pixel_level:
    :return: Eraser to be used as Preprocessing Function
    """
    assert max_erasures_per_image >= 1

    def eraser(input_img):
        v_l = np.min(input_img)
        v_h = np.max(input_img)
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        mx = np.random.randint(1, max_erasures_per_image + 1)
        # print("Erasures = ",mx,end =", ")
        for i in range(mx):
            while True:
                s = np.random.uniform(s_l, s_h) * img_h * img_w
                r = np.random.uniform(r_1, r_2)
                w = int(np.sqrt(s / r))
                h = int(np.sqrt(s * r))
                left = np.random.randint(0, img_w)
                top = np.random.randint(0, img_h)

                if left + w <= img_w and top + h <= img_h:
                    break

            # print("W = ",w,"H = ",h,end =", ")

            if pixel_level:
                # print(np.max(img_c),np.min(img_c),v_l,v_h)
                c = np.random.uniform(v_l, v_h, (h, w, img_c))
                # print(c.shape,np.min(c),np.max(c),np.median(c))
            else:
                c = np.random.uniform(v_l, v_h)

            input_img[top:top + h, left:left + w, :] = c

        # print()
        return input_img
      
    def random_crop(input_img):
        # Note: image_data_format is 'channel_last'
        assert input_img.shape[2] == 3
        
        img = cv2.copyMakeBorder(input_img, padding_for_crop, padding_for_crop, padding_for_crop, padding_for_crop, cv2.BORDER_REPLICATE)
        
        height, width = img.shape[0], img.shape[1]
        
        dy, dx = random_crop_size
        
        x = np.random.randint(0, width - dx + 1)
        
        y = np.random.randint(0, height - dy + 1)
        
        return img[y:(y+dy), x:(x+dx), :]
      
    def do_preproc(input_image):
      return eraser(random_crop(input_image))
      
    return do_preproc
  
# Min-Max scale  
def min_max_scale(X):
    return (X - np.min(X))/(np.max(X)-np.min(X))  
  
def denormalize(img):
  return (img*datagen_validation.std + datagen_validation.mean)/255  

# learning rate schedule
def step_decay(epoch):
	initial_lrate = 0.1
	drop = 0.5
	epochs_drop = 10.0
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

# %% [markdown]
# # # 3. OneCycleLR class

# %%
import os
import numpy as np
import warnings

from keras.callbacks import Callback
from keras import backend as K


# Code is ported from https://github.com/fastai/fastai
class OneCycleLR(Callback):
    def __init__(self,
                 epochs,
                 batch_size,
                 samples,
                 steps,
                 max_lr,
                 end_percentage=0.1,
                 scale_percentage=None,
                 maximum_momentum=0.95,
                 minimum_momentum=0.85,
                 verbose=True):
        """ This callback implements a cyclical learning rate policy (CLR).
        This is a special case of Cyclic Learning Rates, where we have only 1 cycle.
        After the completion of 1 cycle, the learning rate will decrease rapidly to
        100th its initial lowest value.
        # Arguments:
            max_lr: Float. Initial learning rate. This also sets the
                starting learning rate (which will be 10x smaller than
                this), and will increase to this value during the first cycle.
            end_percentage: Float. The percentage of all the epochs of training
                that will be dedicated to sharply decreasing the learning
                rate after the completion of 1 cycle. Must be between 0 and 1.
            scale_percentage: Float or None. If float, must be between 0 and 1.
                If None, it will compute the scale_percentage automatically
                based on the `end_percentage`.
            maximum_momentum: Optional. Sets the maximum momentum (initial)
                value, which gradually drops to its lowest value in half-cycle,
                then gradually increases again to stay constant at this max value.
                Can only be used with SGD Optimizer.
            minimum_momentum: Optional. Sets the minimum momentum at the end of
                the half-cycle. Can only be used with SGD Optimizer.
            verbose: Bool. Whether to print the current learning rate after every
                epoch.
        # Reference
            - [A disciplined approach to neural network hyper-parameters: Part 1 -- learning rate, batch size, weight_decay, and weight decay](https://arxiv.org/abs/1803.09820)
            - [Super-Convergence: Very Fast Training of Residual Networks Using Large Learning Rates](https://arxiv.org/abs/1708.07120)
        """
        super(OneCycleLR, self).__init__()

        if end_percentage < 0. or end_percentage > 1.:
            raise ValueError("`end_percentage` must be between 0 and 1")

        if scale_percentage is not None and (scale_percentage < 0. or scale_percentage > 1.):
            raise ValueError("`scale_percentage` must be between 0 and 1")

        self.initial_lr = max_lr
        self.end_percentage = end_percentage
        self.scale = float(scale_percentage) if scale_percentage is not None else float(end_percentage)
        self.max_momentum = maximum_momentum
        self.min_momentum = minimum_momentum
        self.verbose = verbose

        if self.max_momentum is not None and self.min_momentum is not None:
            self._update_momentum = True
        else:
            self._update_momentum = False

        self.clr_iterations = 0.
        self.history = {}

        self.epochs = epochs
        self.batch_size = batch_size
        self.samples = samples
        self.steps = steps
        self.num_iterations = None
        self.mid_cycle_id = None

    def _reset(self):
        """
        Reset the callback.
        """
        self.clr_iterations = 0.
        self.history = {}

    def compute_lr(self):
        """
        Compute the learning rate based on which phase of the cycle it is in.
        - If in the first half of training, the learning rate gradually increases.
        - If in the second half of training, the learning rate gradually decreases.
        - If in the final `end_percentage` portion of training, the learning rate
            is quickly reduced to near 100th of the original min learning rate.
        # Returns:
            the new learning rate
        """
        if self.clr_iterations > 2 * self.mid_cycle_id:
            current_percentage = (self.clr_iterations - 2 * self.mid_cycle_id)
            current_percentage /= float((self.num_iterations - 2 * self.mid_cycle_id))
            new_lr = self.initial_lr * (1. + (current_percentage *
                                              (1. - 100.) / 100.)) * self.scale

        elif self.clr_iterations > self.mid_cycle_id:
            current_percentage = 1. - (
                    self.clr_iterations - self.mid_cycle_id) / self.mid_cycle_id
            new_lr = self.initial_lr * (1. + current_percentage *
                                        (self.scale * 100 - 1.)) * self.scale

        else:
            current_percentage = self.clr_iterations / self.mid_cycle_id
            new_lr = self.initial_lr * (1. + current_percentage *
                                        (self.scale * 100 - 1.)) * self.scale

        if self.clr_iterations == self.num_iterations:
            self.clr_iterations = 0

        return new_lr

    def compute_momentum(self):
        """
         Compute the momentum based on which phase of the cycle it is in.
        - If in the first half of training, the momentum gradually decreases.
        - If in the second half of training, the momentum gradually increases.
        - If in the final `end_percentage` portion of training, the momentum value
            is kept constant at the maximum initial value.
        # Returns:
            the new momentum value
        """
        if self.clr_iterations > 2 * self.mid_cycle_id:
            new_momentum = self.max_momentum

        elif self.clr_iterations > self.mid_cycle_id:
            current_percentage = 1. - ((self.clr_iterations - self.mid_cycle_id) / float(
                self.mid_cycle_id))
            new_momentum = self.max_momentum - current_percentage * (
                    self.max_momentum - self.min_momentum)

        else:
            current_percentage = self.clr_iterations / float(self.mid_cycle_id)
            new_momentum = self.max_momentum - current_percentage * (
                    self.max_momentum - self.min_momentum)

        return new_momentum

    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.steps is not None:
            self.num_iterations = self.epochs * self.steps
        else:
            if (self.samples % self.batch_size) == 0:
                remainder = 0
            else:
                remainder = 1
            self.num_iterations = (self.epochs + remainder) * self.samples // self.batch_size

        self.mid_cycle_id = int(self.num_iterations * ((1. - self.end_percentage)) / float(2))

        self._reset()
        K.set_value(self.model.optimizer.lr, self.compute_lr())

        if self._update_momentum:
            if not hasattr(self.model.optimizer, 'momentum'):
                raise ValueError("Momentum can be updated only on SGD optimizer !")

            new_momentum = self.compute_momentum()
            K.set_value(self.model.optimizer.momentum, new_momentum)

    def on_batch_end(self, epoch, logs=None):
        logs = logs or {}

        self.clr_iterations += 1
        new_lr = self.compute_lr()

        self.history.setdefault('lr', []).append(
            K.get_value(self.model.optimizer.lr))
        K.set_value(self.model.optimizer.lr, new_lr)

        if self._update_momentum:
            if not hasattr(self.model.optimizer, 'momentum'):
                raise ValueError("Momentum can be updated only on SGD optimizer !")

            new_momentum = self.compute_momentum()

            self.history.setdefault('momentum', []).append(
                K.get_value(self.model.optimizer.momentum))
            K.set_value(self.model.optimizer.momentum, new_momentum)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

    def on_epoch_end(self, epoch, logs=None):
        if self.verbose:
            if self._update_momentum:
                print(" - lr: %0.5f - momentum: %0.2f " %
                      (self.history['lr'][-1], self.history['momentum'][-1]))

            else:
                print(" - lr: %0.5f " % (self.history['lr'][-1]))

# %% [markdown]
# # # 4. LR Finder class

# %%
import os
import numpy as np
import warnings

from keras.callbacks import Callback
from keras import backend as K

import numpy as np
import scipy.ndimage.filters as filters
import scipy.ndimage.morphology as morphology
import pandas as pd


def detect_local_minima(arr):
    # https://stackoverflow.com/questions/4624970/finding-local-maxima-minima-with-numpy-in-a-1d-numpy-array
    # https://stackoverflow.com/questions/3986345/how-to-find-the-local-minima-of-a-smooth-multidimensional-array-in-numpy-efficien
    # https://stackoverflow.com/questions/3684484/peak-detection-in-a-2d-array/3689710#3689710
    """
    Takes an array and detects the troughs using the local maximum filter.
    Returns a boolean mask of the troughs (i.e. 1 when
    the pixel's value is the neighborhood maximum, 0 otherwise)
    """
    # define an connected neighborhood
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.morphology.html#generate_binary_structure
    neighborhood = morphology.generate_binary_structure(len(arr.shape), 2)
    # apply the local minimum filter; all locations of minimum value
    # in their neighborhood are set to 1
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.filters.html#minimum_filter
    local_min = (filters.minimum_filter(arr, footprint=neighborhood) == arr)
    # local_min is a mask that contains the peaks we are
    # looking for, but also the background.
    # In order to isolate the peaks we must remove the background from the mask.
    #
    # we create the mask of the background
    background = (arr == 0)
    #
    # a little technicality: we must erode the background in order to
    # successfully subtract it from local_min, otherwise a line will
    # appear along the background border (artifact of the local minimum filter)
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.morphology.html#binary_erosion
    eroded_background = morphology.binary_erosion(
        background, structure=neighborhood, border_value=1)
    #
    # we obtain the final mask, containing only peaks,
    # by removing the background from the local_min mask
    detected_minima = local_min ^ eroded_background
    return np.where(detected_minima)


def moving_average_fast(x, w):
    # https://stackoverflow.com/questions/14313510/how-to-calculate-moving-average-using-numpy
    return np.convolve(np.array(x), np.ones(w), 'same') / w


def moving_average(x, w):
    df = pd.DataFrame({"x": x})
    return df.rolling(w, win_type=None, min_periods=1, center=True).mean()['x'].values


from matplotlib import pyplot as plt
import math
from keras.callbacks import LambdaCallback
import keras.backend as K
import numpy as np


class LRFinder:
    """
    Plots the change of the loss function of a Keras model when the learning rate is exponentially increasing.
    See for details:
    https://towardsdatascience.com/estimating-optimal-learning-rate-for-a-deep-neural-network-ce32f2556ce0
    """

    def __init__(self, model, num_validation_batches=10):
        self.model = model
        self.losses = []
        self.lrs = []
        self.best_loss = 1e9
        self.num_validation_batches = num_validation_batches
        self.validation_set = None
        self.validation_generator = None

    def on_batch_end(self, batch, logs):
        # Log the learning rate
        lr = K.get_value(self.model.optimizer.lr)
        self.lrs.append(lr)

        # Log the loss

        if self.validation_set is not None:
            X, Y = self.validation_set[0], self.validation_set[1]

            # use 10 random batches from test set for fast approximate of loss
            num_samples = self.batch_size * self.num_validation_batches

            if num_samples > X.shape[0]:
                num_samples = X.shape[0]

            idx = np.random.choice(X.shape[0], num_samples, replace=False)
            x = X[idx]
            y = Y[idx]

            values = self.model.evaluate(x, y, batch_size=self.batch_size, verbose=False)
            loss = values[0]
        elif self.validation_generator is not None:
            values = self.model.evaluate_generator(self.validation_generator, steps=self.num_validation_batches, )
            # print(values[0],logs['loss'])
            loss = values[0]
        else:
            loss = logs['loss']

        self.losses.append(loss)

        # Check whether the loss got too large or NaN
        if batch > 10 and (math.isnan(loss) or loss > self.best_loss * 8):
            self.model.stop_training = True
            print("Stop Training at %s, loss = %.3f" % (batch, loss))
            return

        if loss < self.best_loss:
            self.best_loss = loss

        # Increase the learning rate for the next batch
        lr *= self.lr_mult
        K.set_value(self.model.optimizer.lr, lr)

    def find(self, x_train, y_train, start_lr, end_lr,
             x_test=None, y_test=None,
             batch_size=64, epochs=1):
        num_batches = epochs * x_train.shape[0] / batch_size
        self.lr_mult = (float(end_lr) / float(start_lr)) ** (float(1) / float(num_batches))

        # Save weights into a file
        self.model.save_weights('tmp.h5')

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch, logs: self.on_batch_end(batch, logs))
        self.validation_set = (x_test, y_test) if x_test is not None and y_test is not None else None
        self.batch_size = batch_size

        self.model.fit(x_train, y_train,
                       batch_size=batch_size, epochs=epochs,
                       verbose=0,
                       callbacks=[callback])

        # Restore the weights to the state before model fitting
        self.model.load_weights('tmp.h5')

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def find_generator(self, generator, start_lr, end_lr,
                       test_generator=None,
                       epochs=1, steps_per_epoch=None, **kw_fit):
        if steps_per_epoch is None:
            try:
                steps_per_epoch = len(generator)
            except (ValueError, NotImplementedError) as e:
                raise e('`steps_per_epoch=None` is only valid for a'
                        ' generator based on the '
                        '`keras.utils.Sequence`'
                        ' class. Please specify `steps_per_epoch` '
                        'or use the `keras.utils.Sequence` class.')
        self.lr_mult = (float(end_lr) / float(start_lr)) ** (float(1) / float(steps_per_epoch * epochs))

        # Save weights into a file
        self.model.save_weights('tmp.h5')

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch,
                                                      logs: self.on_batch_end(batch, logs))

        self.validation_generator = test_generator

        self.model.fit_generator(generator=generator,
                                 epochs=epochs,
                                 steps_per_epoch=steps_per_epoch,
                                 callbacks=[callback],
                                 verbose=0,
                                 **kw_fit)

        # Restore the weights to the state before model fitting
        self.model.load_weights('tmp.h5')

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def plot_loss(self, n_skip_beginning=5, n_skip_end=5, sma=10):
        """
        Plots the loss.
        Parameters:
            n_skip_beginning - number of batches to skip on the left.
            n_skip_end - number of batches to skip on the right.
        """
        fig = plt.figure(figsize=(12, 6))
        ax = fig.add_subplot(111)
        plt.ylabel("loss")
        plt.xlabel("learning rate (log scale)")

        losses = self.losses
        losses = moving_average(losses, sma)

        losses = losses[n_skip_beginning:-n_skip_end]

        plt.plot(self.lrs[n_skip_beginning:-n_skip_end], losses)
        plt.xscale('log')
        best_lrs = self.get_best_lrs(sma)
        lrs = [x for x, _ in best_lrs]
        positions = [x for _, x in best_lrs]
        # https://matplotlib.org/users/annotations_intro.html
        for lr, pos in [best_lrs[-1]]:
            ax.annotate('LR = %.3f, Loss = %.3f' % (lr, losses[pos]), xy=(lr, losses[pos]),
                        xytext=(lr + 0.2, losses[pos] + 0.1),
                        arrowprops=dict(facecolor='black', shrink=0.03, width=1, frac=0.05),
                        )

        title = "LR-Loss Graph"
        title = title + "\n" + "Best Candidate LR = %s" % lrs
        title = title + "\n" + "These Candidate LRs denote the positions of minima/troughs in LR-Loss graph"
        plt.title(title)
        plt.show()

    def get_derivatives(self, sma=10):
        assert sma >= 1
        derivatives = [0] * sma
        losses = moving_average(self.losses, 5)
        for i in range(sma, len(self.lrs)):
            derivatives.append((losses[i] - losses[i - sma]) / sma)
        return derivatives

    def __get_best_lr_method1__(self, sma, n_skip_beginning=10, n_skip_end=5):
        derivatives = self.get_derivatives(sma)
        losses = np.array(self.losses[n_skip_beginning:-n_skip_end])
        derivatives = derivatives[n_skip_beginning:-n_skip_end]
        lrs = self.lrs[n_skip_beginning:-n_skip_end]

        idxs = np.where(losses >= self.best_loss * 2)[0]
        idxs = idxs[0]
        derivatives = derivatives[:idxs + sma]
        losses = losses[:idxs + sma]
        lrs = lrs[:idxs + sma]

        best_idxs = np.argpartition(derivatives[:idxs], -5)[-5:]
        best_idxs = best_idxs - sma
        acceptable_loss_or_not = losses[best_idxs] <= self.best_loss * 4
        best_idxs = best_idxs[acceptable_loss_or_not]

        acceptable_loss_or_not = losses[best_idxs + sma] > (losses[best_idxs] * 1.05)
        best_idxs = best_idxs[acceptable_loss_or_not]

        candidates = list(np.array(lrs)[best_idxs])
        return sorted(candidates), best_idxs

    def get_best_lrs(self, sma, n_skip_beginning=10, n_skip_end=5):
        c1, i1 = self.__get_best_lr_method1__(sma, n_skip_beginning, n_skip_end)
        candidates = list(zip(c1, i1))
        candidates = sorted(candidates, key=lambda pair: pair[0])
        final_candidates = [candidates[0]]
        for v, i in candidates:
            if (v - final_candidates[-1][0]) / final_candidates[-1][0] > 0.2:
                final_candidates.append((v, i))
        final_candidates = list(map(lambda pair: (float("%.3f" % pair[0]), pair[1]), final_candidates))
        return final_candidates

# %% [markdown]
# # # 5. Normalization

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 128

#  load cifar10 data  
(train_features, train_labels), (test_features, test_labels) = get_cifar10_data()

cutout_fn = get_cutout_eraser(p=0.75, s_l=0.1, s_h=0.3, r_1=0.3, r_2=1 / 0.3, 
                              max_erasures_per_image=2, 
                              random_crop_size=(32, 32), 
                              padding_for_crop=4, 
                              pixel_level=True)

datagen = ImageDataGenerator(featurewise_center=True,
                             featurewise_std_normalization=(0.4914, 0.4822, 0.4465),  
                             samplewise_std_normalization=(0.2023, 0.1994, 0.2010),
#                              featurewise_std_normalization=True,
#                              rotation_range=0,       # randomly rotate images in the range (degrees, 0 to 180)
#                              width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#                              height_shift_range=0.1, # randomly shift images vertically (fraction of total height)
                             horizontal_flip=0.5,   # randomly flip images
#                              vertical_flip=False,    # randomly flip images                             
                             preprocessing_function=cutout_fn)
datagen.fit(train_features)

datagen_validation = ImageDataGenerator(featurewise_center=True,
                                        featurewise_std_normalization=(0.4914, 0.4822, 0.4465),
                                        samplewise_std_normalization=(0.2023, 0.1994, 0.2010),
#                                         featurewise_std_normalization=True,
#                                         rotation_range=0,       # randomly rotate images in the range (degrees, 0 to 180)
#                                         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#                                         height_shift_range=0.1, # randomly shift images vertically (fraction of total height)
                                        horizontal_flip=0.5,   # randomly flip images
#                                         vertical_flip=False,    # randomly flip images                                            
                                       )
datagen_validation.fit(train_features)


# train_features_mean = np.mean(train_features, axis=(0,1,2))
# train_features_std  = np.std(train_features, axis=(0,1,2))

# train_features = (train_features - train_features_mean) / train_features_std
# test_features  = (test_features - train_features_mean) / train_features_std

show_examples(train_features[0:10], train_labels[0:10], classes=get_cifar10_labels())
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# # # 6. Create the model: ResNet18
#
# > ![ResNet18](https://rashidmeras.github.io/images/eva/ResNet18.png)

# %%
# Define the ResNet18 blocks
def Block1(x):
  t   = ZeroPadding2D(padding=(1, 1))(x)
  x1  = Conv2D(64, kernel_size=3, activation='relu')(t)#56,64
  x2  = BatchNormalization()(x1)
  t1  = ZeroPadding2D(padding=(1, 1))(x2)
  x3  = Conv2D(64, kernel_size=3, activation='relu')(t1)#56,64
  x4  = BatchNormalization()(x3)
  x5  = add([x,x4])
  t2  = ZeroPadding2D(padding=(1, 1))(x5)
  x6  = Conv2D(64, kernel_size=3, activation='relu')(t2)#56,64
  x7  = BatchNormalization()(x6)
  t3  = ZeroPadding2D(padding=(1, 1))(x7)
  x8  = Conv2D(64, kernel_size=3, activation='relu')(t3)#56,64
  x9  = BatchNormalization()(x8)
  x10 = add([x5,x9])
  return (x10)

def Block2(x):
  t   = ZeroPadding2D(padding=(1, 1))(x)
  x1  = Conv2D(128, kernel_size=3, activation='relu', strides=2)(t)#26,128
  x2  = BatchNormalization()(x1)
  t1  = ZeroPadding2D(padding=(1, 1))(x2)
  x3  = Conv2D(128, kernel_size=3, activation='relu')(t1)#26,128
  x4  = BatchNormalization()(x3)
  r   = Conv2D(128, kernel_size=1, activation='relu',strides=2)(x)
  x5  = add([r,x4])
  t2  = ZeroPadding2D(padding=(1, 1))(x5)
  x6  = Conv2D(128, kernel_size=3, activation='relu')(t2)#26,128
  x7  = BatchNormalization()(x6)
  t3  = ZeroPadding2D(padding=(1, 1))(x7)
  x8  = Conv2D(128, kernel_size=3, activation='relu')(t3)#26,128
  x9  = BatchNormalization()(x8)
  x10 = add([x5,x9])
  return (x10)

def Block3(x):
  t   = ZeroPadding2D(padding=(1, 1))(x)
  x1  = Conv2D(256, kernel_size=3, activation='relu', strides=2)(t)#56,64
  x2  = BatchNormalization()(x1)
  t1  = ZeroPadding2D(padding=(1, 1))(x2)
  x3  = Conv2D(256, kernel_size=3, activation='relu')(t1)#56,64
  x4  = BatchNormalization()(x3)
  r   = Conv2D(256, kernel_size=1, activation='relu',strides=2)(x)
  x5  = add([r,x4])
  t2  = ZeroPadding2D(padding=(1, 1))(x5)
  x6  = Conv2D(256, kernel_size=3, activation='relu')(t2)#56,64
  x7  = BatchNormalization()(x6)
  t3  = ZeroPadding2D(padding=(1, 1))(x7)
  x8  = Conv2D(256, kernel_size=3, activation='relu')(t3)#56,64
  x9  = BatchNormalization()(x8)
  x10 = add([x5,x9])
  return (x10)

def Block4(x):
  t   = ZeroPadding2D(padding=(1, 1))(x)
  x1  = Conv2D(512, kernel_size=3, activation='relu', strides=2)(t)#56,64
  x2  = BatchNormalization()(x1)
  t1  = ZeroPadding2D(padding=(1, 1))(x2)
  x3  = Conv2D(512, kernel_size=3, activation='relu')(t1)#56,64
  x4  = BatchNormalization()(x3)
  r   = Conv2D(512, kernel_size=1, activation='relu',strides=2)(x)
  x5  = add([r,x4])
  t2  = ZeroPadding2D(padding=(1, 1))(x5)
  x6  = Conv2D(512, kernel_size=3, activation='relu')(t2)#56,64
  x7  = BatchNormalization()(x6)
  t3  = ZeroPadding2D(padding=(1, 1))(x7)
  x8  = Conv2D(512, kernel_size=3, activation='relu')(t3)#56,64
  x9  = BatchNormalization()(x8)
  x10 = add([x5,x9])
  return (x10)

# Define the model
def build_model(summary=False, lrate=0.0):
    
    input = Input(shape=(32, 32, 3,))
        
    t  = ZeroPadding2D(padding=(3, 3))(input)
    x1 = Conv2D(64, kernel_size=3, activation='relu',strides= 2)(t)#112,64
    t1 = BatchNormalization()(x1)
    x2 = MaxPooling2D(pool_size=(2, 2),)(t1)#56,64
    x3 = Block1(x2)
    x4 = Block2(x3)
    x5 = Block3(x4)
    x6 = Block4(x5)
    x7 = Convolution2D(10, 1, 1) (x6)
    x8 = AveragePooling2D()(x7)

    x = Flatten() (x8)

    output = Activation('softmax') (x)
    
    model = Model(inputs=[input], outputs=[output])
    
    sgd = SGD(lr=lrate, momentum=0.9, decay=5e-4, nesterov=False)
  
    model.compile(optimizer= sgd,
                  loss = 'binary_crossentropy',
                  metrics=['accuracy'])    
    
    #Print model summary
    if (summary == True):
        model.summary()
    
    return model

# %% [markdown]
# # # 7. Implement the function to train the network

# %%
def train_network(model, epochs=25, lr_scheduling_fn=None, one_cycle_start_lr=None, step_decay_lr=False):
      
    save_mcp = ModelCheckpoint('best_model_Ass13.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
          
    train_iterator      = datagen.flow(train_features, train_labels, batch_size=batch_size, shuffle=True)
    validation_iterator = datagen_validation.flow(test_features, test_labels, batch_size=batch_size, shuffle=True)
    
    callbacks=[save_mcp]
    lr_schedule = LearningRateScheduler(lr_scheduling_fn) if lr_scheduling_fn is not None else None
    
    lr_step = LearningRateScheduler(step_decay) if step_decay_lr is True else None
    
    if lr_schedule is not None:
       callbacks.append(lr_schedule)
        
    if lr_step is not None:
      callbacks.append(lr_step)      
        
    ################OneCycleLR###################################        
    if one_cycle_start_lr is not None:             
      lr_one_cycle = OneCycleLR(epochs=epochs,
                                batch_size=batch_size,
                                samples = len(test_labels),
                                steps = len(train_iterator),
                                max_lr=one_cycle_start_lr)  
      callbacks.append(lr_one_cycle) 
    #############################################################        
    
    # Train the model
    start = time.time() 
                              
    train_history = model.fit_generator(train_iterator,
                                        steps_per_epoch  = len(train_iterator), 
                                        validation_data  = validation_iterator, 
                                        validation_steps = len(validation_iterator),
                                        epochs           = epochs, 
                                        verbose          = 2,
                                        callbacks        = callbacks)    

    model.load_weights("best_model_Ass13.h5")
      
    end = time.time()
    print ("Model took %0.2f seconds to train \n"%(end - start))

    # plot model history
    if (epochs > 1):
        plot_model_history(train_history)

    return train_history

# %% [markdown]
# # # 8. Build the model

# %%
model = build_model(summary=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 18, 18, 64)   1792        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 18, 18, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 9, 9, 64)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 11, 11, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 9, 64)     36928       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 9, 9, 64)     256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 11, 11, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 9, 9, 64)     36928       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 9, 9, 64)     256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 9, 9, 64)     0           max_pooling2d_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 11, 11, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 9, 9, 64)     36928       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 9, 9, 64)     256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 11, 11, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 9, 9, 64)     36928       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 9, 9, 64)     256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 9, 9, 64)     0           add_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 11, 11, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 5, 5, 128)    73856       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 5, 5, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 7, 7, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 5, 5, 128)    147584      zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 5, 5, 128)    8320        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 5, 5, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 5, 5, 128)    0           conv2d_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 7, 7, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 5, 5, 128)    147584      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 5, 5, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 7, 7, 128)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 5, 5, 128)    147584      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 5, 5, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 5, 5, 128)    0           add_3[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 7, 7, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 3, 3, 256)    295168      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 3, 3, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 5, 5, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 3, 3, 256)    590080      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 3, 3, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 3, 3, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 3, 3, 256)    0           conv2d_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 5, 5, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 3, 3, 256)    590080      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 3, 3, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 5, 5, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 3, 3, 256)    590080      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 3, 3, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 3, 3, 256)    0           add_5[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 5, 5, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 512)    1180160     zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 2, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 4, 4, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 512)    2359808     zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 512)    131584      add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 2, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 512)    0           conv2d_18[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 512)    2359808     zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 2, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 4, 4, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 512)    2359808     zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2, 2, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 512)    0           add_7[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 10)     5130        add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 10)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 11,184,778
# Trainable params: 11,176,970
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %% [markdown]
# # # 9. Dry run: Train the network for 100 epochs

# %%
train_history = train_network(model, epochs=100, step_decay_lr=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/100
#  - 29s - loss: 0.2568 - acc: 0.9057 - val_loss: 0.2103 - val_acc: 0.9165
#
# Epoch 00001: val_acc improved from -inf to 0.91647, saving model to best_model_Ass13.h5
# Epoch 2/100
#  - 22s - loss: 0.2180 - acc: 0.9157 - val_loss: 0.1911 - val_acc: 0.9239
#
# Epoch 00002: val_acc improved from 0.91647 to 0.92393, saving model to best_model_Ass13.h5
# Epoch 3/100
#  - 22s - loss: 0.2032 - acc: 0.9207 - val_loss: 0.1713 - val_acc: 0.9310
#
# Epoch 00003: val_acc improved from 0.92393 to 0.93105, saving model to best_model_Ass13.h5
# Epoch 4/100
#  - 22s - loss: 0.1925 - acc: 0.9246 - val_loss: 0.1607 - val_acc: 0.9362
#
# Epoch 00004: val_acc improved from 0.93105 to 0.93617, saving model to best_model_Ass13.h5
# Epoch 5/100
#  - 22s - loss: 0.1835 - acc: 0.9275 - val_loss: 0.1578 - val_acc: 0.9373
#
# Epoch 00005: val_acc improved from 0.93617 to 0.93731, saving model to best_model_Ass13.h5
# Epoch 6/100
#  - 22s - loss: 0.1761 - acc: 0.9304 - val_loss: 0.1459 - val_acc: 0.9423
#
# Epoch 00006: val_acc improved from 0.93731 to 0.94234, saving model to best_model_Ass13.h5
# Epoch 7/100
#  - 22s - loss: 0.1709 - acc: 0.9326 - val_loss: 0.1465 - val_acc: 0.9422
#
# Epoch 00007: val_acc did not improve from 0.94234
# Epoch 8/100
#  - 22s - loss: 0.1652 - acc: 0.9347 - val_loss: 0.1360 - val_acc: 0.9464
#
# Epoch 00008: val_acc improved from 0.94234 to 0.94642, saving model to best_model_Ass13.h5
# Epoch 9/100
#  - 22s - loss: 0.1605 - acc: 0.9364 - val_loss: 0.1311 - val_acc: 0.9483
#
# Epoch 00009: val_acc improved from 0.94642 to 0.94830, saving model to best_model_Ass13.h5
# Epoch 10/100
#  - 22s - loss: 0.1526 - acc: 0.9397 - val_loss: 0.1246 - val_acc: 0.9512
#
# Epoch 00010: val_acc improved from 0.94830 to 0.95116, saving model to best_model_Ass13.h5
# Epoch 11/100
#  - 22s - loss: 0.1495 - acc: 0.9410 - val_loss: 0.1221 - val_acc: 0.9524
#
# Epoch 00011: val_acc improved from 0.95116 to 0.95237, saving model to best_model_Ass13.h5
# Epoch 12/100
#  - 22s - loss: 0.1477 - acc: 0.9414 - val_loss: 0.1214 - val_acc: 0.9527
#
# Epoch 00012: val_acc improved from 0.95237 to 0.95272, saving model to best_model_Ass13.h5
# Epoch 13/100
#  - 22s - loss: 0.1458 - acc: 0.9422 - val_loss: 0.1188 - val_acc: 0.9533
#
# Epoch 00013: val_acc improved from 0.95272 to 0.95328, saving model to best_model_Ass13.h5
# Epoch 14/100
#  - 23s - loss: 0.1439 - acc: 0.9426 - val_loss: 0.1210 - val_acc: 0.9522
#
# Epoch 00014: val_acc did not improve from 0.95328
# Epoch 15/100
#  - 22s - loss: 0.1426 - acc: 0.9436 - val_loss: 0.1202 - val_acc: 0.9533
#
# Epoch 00015: val_acc improved from 0.95328 to 0.95328, saving model to best_model_Ass13.h5
# Epoch 16/100
#  - 22s - loss: 0.1405 - acc: 0.9443 - val_loss: 0.1147 - val_acc: 0.9550
#
# Epoch 00016: val_acc improved from 0.95328 to 0.95502, saving model to best_model_Ass13.h5
# Epoch 17/100
#  - 22s - loss: 0.1387 - acc: 0.9455 - val_loss: 0.1171 - val_acc: 0.9549
#
# Epoch 00017: val_acc did not improve from 0.95502
# Epoch 18/100
#  - 22s - loss: 0.1385 - acc: 0.9452 - val_loss: 0.1129 - val_acc: 0.9558
#
# Epoch 00018: val_acc improved from 0.95502 to 0.95583, saving model to best_model_Ass13.h5
# Epoch 19/100
#  - 22s - loss: 0.1372 - acc: 0.9459 - val_loss: 0.1116 - val_acc: 0.9560
#
# Epoch 00019: val_acc improved from 0.95583 to 0.95602, saving model to best_model_Ass13.h5
# Epoch 20/100
#  - 22s - loss: 0.1341 - acc: 0.9469 - val_loss: 0.1100 - val_acc: 0.9566
#
# Epoch 00020: val_acc improved from 0.95602 to 0.95656, saving model to best_model_Ass13.h5
# Epoch 21/100
#  - 22s - loss: 0.1339 - acc: 0.9471 - val_loss: 0.1089 - val_acc: 0.9575
#
# Epoch 00021: val_acc improved from 0.95656 to 0.95753, saving model to best_model_Ass13.h5
# Epoch 22/100
#  - 22s - loss: 0.1314 - acc: 0.9481 - val_loss: 0.1092 - val_acc: 0.9572
#
# Epoch 00022: val_acc did not improve from 0.95753
# Epoch 23/100
#  - 22s - loss: 0.1307 - acc: 0.9486 - val_loss: 0.1081 - val_acc: 0.9578
#
# Epoch 00023: val_acc improved from 0.95753 to 0.95785, saving model to best_model_Ass13.h5
# Epoch 24/100
#  - 22s - loss: 0.1310 - acc: 0.9482 - val_loss: 0.1101 - val_acc: 0.9571
#
# Epoch 00024: val_acc did not improve from 0.95785
# Epoch 25/100
#  - 22s - loss: 0.1298 - acc: 0.9488 - val_loss: 0.1076 - val_acc: 0.9579
#
# Epoch 00025: val_acc improved from 0.95785 to 0.95789, saving model to best_model_Ass13.h5
# Epoch 26/100
#  - 22s - loss: 0.1297 - acc: 0.9489 - val_loss: 0.1073 - val_acc: 0.9583
#
# Epoch 00026: val_acc improved from 0.95789 to 0.95833, saving model to best_model_Ass13.h5
# Epoch 27/100
#  - 22s - loss: 0.1304 - acc: 0.9484 - val_loss: 0.1072 - val_acc: 0.9578
#
# Epoch 00027: val_acc did not improve from 0.95833
# Epoch 28/100
#  - 22s - loss: 0.1293 - acc: 0.9490 - val_loss: 0.1068 - val_acc: 0.9584
#
# Epoch 00028: val_acc improved from 0.95833 to 0.95835, saving model to best_model_Ass13.h5
# Epoch 29/100
#  - 22s - loss: 0.1289 - acc: 0.9491 - val_loss: 0.1064 - val_acc: 0.9585
#
# Epoch 00029: val_acc improved from 0.95835 to 0.95852, saving model to best_model_Ass13.h5
# Epoch 30/100
#  - 22s - loss: 0.1282 - acc: 0.9496 - val_loss: 0.1060 - val_acc: 0.9585
#
# Epoch 00030: val_acc improved from 0.95852 to 0.95855, saving model to best_model_Ass13.h5
# Epoch 31/100
#  - 22s - loss: 0.1267 - acc: 0.9498 - val_loss: 0.1059 - val_acc: 0.9584
#
# Epoch 00031: val_acc did not improve from 0.95855
# Epoch 32/100
#  - 22s - loss: 0.1275 - acc: 0.9497 - val_loss: 0.1043 - val_acc: 0.9594
#
# Epoch 00032: val_acc improved from 0.95855 to 0.95939, saving model to best_model_Ass13.h5
# Epoch 33/100
#  - 22s - loss: 0.1270 - acc: 0.9501 - val_loss: 0.1037 - val_acc: 0.9591
#
# Epoch 00033: val_acc did not improve from 0.95939
# Epoch 34/100
#  - 22s - loss: 0.1259 - acc: 0.9503 - val_loss: 0.1043 - val_acc: 0.9591
#
# Epoch 00034: val_acc did not improve from 0.95939
# Epoch 35/100
#  - 22s - loss: 0.1263 - acc: 0.9500 - val_loss: 0.1043 - val_acc: 0.9591
#
# Epoch 00035: val_acc did not improve from 0.95939
# Epoch 36/100
#  - 22s - loss: 0.1261 - acc: 0.9503 - val_loss: 0.1041 - val_acc: 0.9589
#
# Epoch 00036: val_acc did not improve from 0.95939
# Epoch 37/100
#  - 22s - loss: 0.1252 - acc: 0.9506 - val_loss: 0.1048 - val_acc: 0.9587
#
# Epoch 00037: val_acc did not improve from 0.95939
# Epoch 38/100
#  - 22s - loss: 0.1257 - acc: 0.9506 - val_loss: 0.1049 - val_acc: 0.9588
#
# Epoch 00038: val_acc did not improve from 0.95939
# Epoch 39/100
#  - 22s - loss: 0.1257 - acc: 0.9503 - val_loss: 0.1047 - val_acc: 0.9592
#
# Epoch 00039: val_acc did not improve from 0.95939
# Epoch 40/100
#  - 22s - loss: 0.1245 - acc: 0.9510 - val_loss: 0.1041 - val_acc: 0.9593
#
# Epoch 00040: val_acc did not improve from 0.95939
# Epoch 41/100
#  - 22s - loss: 0.1247 - acc: 0.9506 - val_loss: 0.1034 - val_acc: 0.9601
#
# Epoch 00041: val_acc improved from 0.95939 to 0.96010, saving model to best_model_Ass13.h5
# Epoch 42/100
#  - 22s - loss: 0.1244 - acc: 0.9509 - val_loss: 0.1043 - val_acc: 0.9597
#
# Epoch 00042: val_acc did not improve from 0.96010
# Epoch 43/100
#  - 22s - loss: 0.1235 - acc: 0.9513 - val_loss: 0.1040 - val_acc: 0.9593
#
# Epoch 00043: val_acc did not improve from 0.96010
# Epoch 44/100
#  - 22s - loss: 0.1243 - acc: 0.9511 - val_loss: 0.1037 - val_acc: 0.9596
#
# Epoch 00044: val_acc did not improve from 0.96010
# Epoch 45/100
#  - 22s - loss: 0.1246 - acc: 0.9508 - val_loss: 0.1031 - val_acc: 0.9596
#
# Epoch 00045: val_acc did not improve from 0.96010
# Epoch 46/100
#  - 22s - loss: 0.1246 - acc: 0.9505 - val_loss: 0.1037 - val_acc: 0.9593
#
# Epoch 00046: val_acc did not improve from 0.96010
# Epoch 47/100
#  - 22s - loss: 0.1240 - acc: 0.9510 - val_loss: 0.1037 - val_acc: 0.9594
#
# Epoch 00047: val_acc did not improve from 0.96010
# Epoch 48/100
#  - 22s - loss: 0.1240 - acc: 0.9511 - val_loss: 0.1038 - val_acc: 0.9597
#
# Epoch 00048: val_acc did not improve from 0.96010
# Epoch 49/100
#  - 22s - loss: 0.1240 - acc: 0.9511 - val_loss: 0.1037 - val_acc: 0.9594
#
# Epoch 00049: val_acc did not improve from 0.96010
# Epoch 50/100
#  - 22s - loss: 0.1237 - acc: 0.9514 - val_loss: 0.1033 - val_acc: 0.9598
#
# Epoch 00050: val_acc did not improve from 0.96010
# Epoch 51/100
#  - 22s - loss: 0.1239 - acc: 0.9513 - val_loss: 0.1030 - val_acc: 0.9597
#
# Epoch 00051: val_acc did not improve from 0.96010
# Epoch 52/100
#  - 22s - loss: 0.1237 - acc: 0.9511 - val_loss: 0.1027 - val_acc: 0.9600
#
# Epoch 00052: val_acc did not improve from 0.96010
# Epoch 53/100
#  - 22s - loss: 0.1235 - acc: 0.9513 - val_loss: 0.1035 - val_acc: 0.9589
#
# Epoch 00053: val_acc did not improve from 0.96010
# Epoch 54/100
#  - 22s - loss: 0.1235 - acc: 0.9512 - val_loss: 0.1031 - val_acc: 0.9601
#
# Epoch 00054: val_acc did not improve from 0.96010
# Epoch 55/100
#  - 22s - loss: 0.1240 - acc: 0.9512 - val_loss: 0.1041 - val_acc: 0.9593
#
# Epoch 00055: val_acc did not improve from 0.96010
# Epoch 56/100
#  - 23s - loss: 0.1234 - acc: 0.9514 - val_loss: 0.1031 - val_acc: 0.9598
#
# Epoch 00056: val_acc did not improve from 0.96010
# Epoch 57/100
#  - 23s - loss: 0.1230 - acc: 0.9513 - val_loss: 0.1031 - val_acc: 0.9593
#
# Epoch 00057: val_acc did not improve from 0.96010
# Epoch 58/100
#  - 22s - loss: 0.1231 - acc: 0.9517 - val_loss: 0.1035 - val_acc: 0.9591
#
# Epoch 00058: val_acc did not improve from 0.96010
# Epoch 59/100
#  - 22s - loss: 0.1234 - acc: 0.9516 - val_loss: 0.1036 - val_acc: 0.9594
#
# Epoch 00059: val_acc did not improve from 0.96010
# Epoch 60/100
#  - 22s - loss: 0.1233 - acc: 0.9513 - val_loss: 0.1029 - val_acc: 0.9596
#
# Epoch 00060: val_acc did not improve from 0.96010
# Epoch 61/100
#  - 22s - loss: 0.1234 - acc: 0.9512 - val_loss: 0.1024 - val_acc: 0.9596
#
# Epoch 00061: val_acc did not improve from 0.96010
# Epoch 62/100
#  - 22s - loss: 0.1230 - acc: 0.9516 - val_loss: 0.1026 - val_acc: 0.9592
#
# Epoch 00062: val_acc did not improve from 0.96010
# Epoch 63/100
#  - 22s - loss: 0.1232 - acc: 0.9515 - val_loss: 0.1034 - val_acc: 0.9590
#
# Epoch 00063: val_acc did not improve from 0.96010
# Epoch 64/100
#  - 22s - loss: 0.1235 - acc: 0.9512 - val_loss: 0.1032 - val_acc: 0.9598
#
# Epoch 00064: val_acc did not improve from 0.96010
# Epoch 65/100
#  - 22s - loss: 0.1236 - acc: 0.9511 - val_loss: 0.1028 - val_acc: 0.9597
#
# Epoch 00065: val_acc did not improve from 0.96010
# Epoch 66/100
#  - 22s - loss: 0.1233 - acc: 0.9515 - val_loss: 0.1027 - val_acc: 0.9603
#
# Epoch 00066: val_acc improved from 0.96010 to 0.96032, saving model to best_model_Ass13.h5
# Epoch 67/100
#  - 22s - loss: 0.1230 - acc: 0.9515 - val_loss: 0.1029 - val_acc: 0.9597
#
# Epoch 00067: val_acc did not improve from 0.96032
# Epoch 68/100
#  - 22s - loss: 0.1232 - acc: 0.9514 - val_loss: 0.1035 - val_acc: 0.9596
#
# Epoch 00068: val_acc did not improve from 0.96032
# Epoch 69/100
#  - 22s - loss: 0.1229 - acc: 0.9517 - val_loss: 0.1033 - val_acc: 0.9597
#
# Epoch 00069: val_acc did not improve from 0.96032
# Epoch 70/100
#  - 22s - loss: 0.1233 - acc: 0.9514 - val_loss: 0.1034 - val_acc: 0.9594
#
# Epoch 00070: val_acc did not improve from 0.96032
# Epoch 71/100
#  - 22s - loss: 0.1223 - acc: 0.9519 - val_loss: 0.1038 - val_acc: 0.9590
#
# Epoch 00071: val_acc did not improve from 0.96032
# Epoch 72/100
#  - 22s - loss: 0.1235 - acc: 0.9512 - val_loss: 0.1032 - val_acc: 0.9600
#
# Epoch 00072: val_acc did not improve from 0.96032
# Epoch 73/100
#  - 22s - loss: 0.1232 - acc: 0.9513 - val_loss: 0.1032 - val_acc: 0.9595
#
# Epoch 00073: val_acc did not improve from 0.96032
# Epoch 74/100
#  - 22s - loss: 0.1236 - acc: 0.9511 - val_loss: 0.1033 - val_acc: 0.9598
#
# Epoch 00074: val_acc did not improve from 0.96032
# Epoch 75/100
#  - 22s - loss: 0.1225 - acc: 0.9517 - val_loss: 0.1036 - val_acc: 0.9591
#
# Epoch 00075: val_acc did not improve from 0.96032
# Epoch 76/100
#  - 22s - loss: 0.1228 - acc: 0.9512 - val_loss: 0.1027 - val_acc: 0.9599
#
# Epoch 00076: val_acc did not improve from 0.96032
# Epoch 77/100
#  - 22s - loss: 0.1224 - acc: 0.9516 - val_loss: 0.1031 - val_acc: 0.9597
#
# Epoch 00077: val_acc did not improve from 0.96032
# Epoch 78/100
#  - 22s - loss: 0.1236 - acc: 0.9512 - val_loss: 0.1032 - val_acc: 0.9595
#
# Epoch 00078: val_acc did not improve from 0.96032
# Epoch 79/100
#  - 22s - loss: 0.1226 - acc: 0.9516 - val_loss: 0.1033 - val_acc: 0.9592
#
# Epoch 00079: val_acc did not improve from 0.96032
# Epoch 80/100
#  - 22s - loss: 0.1238 - acc: 0.9515 - val_loss: 0.1028 - val_acc: 0.9599
#
# Epoch 00080: val_acc did not improve from 0.96032
# Epoch 81/100
#  - 22s - loss: 0.1225 - acc: 0.9519 - val_loss: 0.1029 - val_acc: 0.9599
#
# Epoch 00081: val_acc did not improve from 0.96032
# Epoch 82/100
#  - 22s - loss: 0.1227 - acc: 0.9516 - val_loss: 0.1038 - val_acc: 0.9591
#
# Epoch 00082: val_acc did not improve from 0.96032
# Epoch 83/100
#  - 22s - loss: 0.1238 - acc: 0.9508 - val_loss: 0.1024 - val_acc: 0.9596
#
# Epoch 00083: val_acc did not improve from 0.96032
# Epoch 84/100
#  - 22s - loss: 0.1231 - acc: 0.9515 - val_loss: 0.1031 - val_acc: 0.9595
#
# Epoch 00084: val_acc did not improve from 0.96032
# Epoch 85/100
#  - 22s - loss: 0.1223 - acc: 0.9520 - val_loss: 0.1032 - val_acc: 0.9597
#
# Epoch 00085: val_acc did not improve from 0.96032
# Epoch 86/100
#  - 22s - loss: 0.1234 - acc: 0.9512 - val_loss: 0.1032 - val_acc: 0.9596
#
# Epoch 00086: val_acc did not improve from 0.96032
# Epoch 87/100
#  - 22s - loss: 0.1228 - acc: 0.9517 - val_loss: 0.1042 - val_acc: 0.9592
#
# Epoch 00087: val_acc did not improve from 0.96032
# Epoch 88/100
#  - 22s - loss: 0.1224 - acc: 0.9520 - val_loss: 0.1033 - val_acc: 0.9595
#
# Epoch 00088: val_acc did not improve from 0.96032
# Epoch 89/100
#  - 22s - loss: 0.1230 - acc: 0.9517 - val_loss: 0.1032 - val_acc: 0.9594
#
# Epoch 00089: val_acc did not improve from 0.96032
# Epoch 90/100
#  - 22s - loss: 0.1229 - acc: 0.9515 - val_loss: 0.1029 - val_acc: 0.9599
#
# Epoch 00090: val_acc did not improve from 0.96032
# Epoch 91/100
#  - 22s - loss: 0.1232 - acc: 0.9512 - val_loss: 0.1032 - val_acc: 0.9601
#
# Epoch 00091: val_acc did not improve from 0.96032
# Epoch 92/100
#  - 22s - loss: 0.1233 - acc: 0.9513 - val_loss: 0.1038 - val_acc: 0.9591
#
# Epoch 00092: val_acc did not improve from 0.96032
# Epoch 93/100
#  - 22s - loss: 0.1223 - acc: 0.9514 - val_loss: 0.1026 - val_acc: 0.9599
#
# Epoch 00093: val_acc did not improve from 0.96032
# Epoch 94/100
#  - 22s - loss: 0.1225 - acc: 0.9519 - val_loss: 0.1026 - val_acc: 0.9600
#
# Epoch 00094: val_acc did not improve from 0.96032
# Epoch 95/100
#  - 22s - loss: 0.1229 - acc: 0.9515 - val_loss: 0.1033 - val_acc: 0.9601
#
# Epoch 00095: val_acc did not improve from 0.96032
# Epoch 96/100
#  - 22s - loss: 0.1234 - acc: 0.9514 - val_loss: 0.1029 - val_acc: 0.9595
#
# Epoch 00096: val_acc did not improve from 0.96032
# Epoch 97/100
#  - 22s - loss: 0.1231 - acc: 0.9513 - val_loss: 0.1029 - val_acc: 0.9596
#
# Epoch 00097: val_acc did not improve from 0.96032
# Epoch 98/100
#  - 22s - loss: 0.1229 - acc: 0.9515 - val_loss: 0.1035 - val_acc: 0.9597
#
# Epoch 00098: val_acc did not improve from 0.96032
# Epoch 99/100
#  - 22s - loss: 0.1234 - acc: 0.9514 - val_loss: 0.1025 - val_acc: 0.9600
#
# Epoch 00099: val_acc did not improve from 0.96032
# Epoch 100/100
#  - 22s - loss: 0.1239 - acc: 0.9511 - val_loss: 0.1027 - val_acc: 0.9597
#
# Epoch 00100: val_acc did not improve from 0.96032
# Model took 2237.65 seconds to train

# %% [markdown]
# # # 10. Run LR Finder to get the best LR

# %%
lrf = LRFinder(model)

generator = datagen.flow(train_features, train_labels, batch_size=batch_size, shuffle=True)                             
test_generator = datagen_validation.flow(test_features, test_labels, batch_size=batch_size, shuffle=True)

lrf.find_generator(generator, 0.0001, 10.0, test_generator, epochs=1, steps_per_epoch=None,)
# lrf.plot_loss()

# %%
lrf.plot_loss()

# %% [markdown]
# # # 11. Run OneCycleLR with the initial LR rate equal to best LR found

# %%
# reset the model weights
model1 = build_model()
train_history = train_network(model1, epochs=100, one_cycle_start_lr=1.099)
# Out:
# Epoch 1/100
#  - 25s - loss: 0.2617 - acc: 0.9046 - val_loss: 0.2163 - val_acc: 0.9139
#
# Epoch 00001: val_acc improved from -inf to 0.91392, saving model to best_model_Ass13.h5
#  - lr: 0.13182 - momentum: 0.95
# Epoch 2/100
#  - 24s - loss: 0.2224 - acc: 0.9142 - val_loss: 0.1869 - val_acc: 0.9258
#
# Epoch 00002: val_acc improved from 0.91392 to 0.92579, saving model to best_model_Ass13.h5
#  - lr: 0.15380 - momentum: 0.95
# Epoch 3/100
#  - 23s - loss: 0.2064 - acc: 0.9194 - val_loss: 0.1820 - val_acc: 0.9279
#
# Epoch 00003: val_acc improved from 0.92579 to 0.92795, saving model to best_model_Ass13.h5
#  - lr: 0.17578 - momentum: 0.94
# Epoch 4/100
#  - 23s - loss: 0.1937 - acc: 0.9237 - val_loss: 0.1640 - val_acc: 0.9342
#
# Epoch 00004: val_acc improved from 0.92795 to 0.93421, saving model to best_model_Ass13.h5
#  - lr: 0.19776 - momentum: 0.94
# Epoch 5/100
#  - 24s - loss: 0.1852 - acc: 0.9268 - val_loss: 0.1604 - val_acc: 0.9364
#
# Epoch 00005: val_acc improved from 0.93421 to 0.93640, saving model to best_model_Ass13.h5
#  - lr: 0.21974 - momentum: 0.94
# Epoch 6/100
#  - 24s - loss: 0.1770 - acc: 0.9300 - val_loss: 0.1545 - val_acc: 0.9388
#
# Epoch 00006: val_acc improved from 0.93640 to 0.93881, saving model to best_model_Ass13.h5
#  - lr: 0.24172 - momentum: 0.94
# Epoch 7/100
#  - 24s - loss: 0.1693 - acc: 0.9330 - val_loss: 0.1418 - val_acc: 0.9439
#
# Epoch 00007: val_acc improved from 0.93881 to 0.94390, saving model to best_model_Ass13.h5
#  - lr: 0.26370 - momentum: 0.93
# Epoch 8/100
#  - 24s - loss: 0.1626 - acc: 0.9356 - val_loss: 0.1355 - val_acc: 0.9463
#
# Epoch 00008: val_acc improved from 0.94390 to 0.94627, saving model to best_model_Ass13.h5
#  - lr: 0.28568 - momentum: 0.93
# Epoch 9/100
#  - 24s - loss: 0.1582 - acc: 0.9378 - val_loss: 0.1379 - val_acc: 0.9458
#
# Epoch 00009: val_acc did not improve from 0.94627
#  - lr: 0.30766 - momentum: 0.93
# Epoch 10/100
#  - 24s - loss: 0.1534 - acc: 0.9393 - val_loss: 0.1283 - val_acc: 0.9495
#
# Epoch 00010: val_acc improved from 0.94627 to 0.94954, saving model to best_model_Ass13.h5
#  - lr: 0.32964 - momentum: 0.93
# Epoch 11/100
#  - 24s - loss: 0.1486 - acc: 0.9411 - val_loss: 0.1243 - val_acc: 0.9516
#
# Epoch 00011: val_acc improved from 0.94954 to 0.95158, saving model to best_model_Ass13.h5
#  - lr: 0.35162 - momentum: 0.93
# Epoch 12/100
#  - 24s - loss: 0.1457 - acc: 0.9420 - val_loss: 0.1184 - val_acc: 0.9532
#
# Epoch 00012: val_acc improved from 0.95158 to 0.95320, saving model to best_model_Ass13.h5
#  - lr: 0.37360 - momentum: 0.92
# Epoch 13/100
#  - 24s - loss: 0.1411 - acc: 0.9444 - val_loss: 0.1262 - val_acc: 0.9516
#
# Epoch 00013: val_acc did not improve from 0.95320
#  - lr: 0.39558 - momentum: 0.92
# Epoch 14/100
#  - 23s - loss: 0.1394 - acc: 0.9449 - val_loss: 0.1202 - val_acc: 0.9532
#
# Epoch 00014: val_acc improved from 0.95320 to 0.95325, saving model to best_model_Ass13.h5
#  - lr: 0.41756 - momentum: 0.92
# Epoch 15/100
#  - 24s - loss: 0.1369 - acc: 0.9457 - val_loss: 0.1201 - val_acc: 0.9542
#
# Epoch 00015: val_acc improved from 0.95325 to 0.95419, saving model to best_model_Ass13.h5
#  - lr: 0.43954 - momentum: 0.92
# Epoch 16/100
#  - 23s - loss: 0.1335 - acc: 0.9475 - val_loss: 0.1131 - val_acc: 0.9552
#
# Epoch 00016: val_acc improved from 0.95419 to 0.95525, saving model to best_model_Ass13.h5
#  - lr: 0.46152 - momentum: 0.91
# Epoch 17/100
#  - 23s - loss: 0.1305 - acc: 0.9486 - val_loss: 0.1156 - val_acc: 0.9541
#
# Epoch 00017: val_acc did not improve from 0.95525
#  - lr: 0.48350 - momentum: 0.91
# Epoch 18/100
#  - 24s - loss: 0.1296 - acc: 0.9488 - val_loss: 0.1052 - val_acc: 0.9592
#
# Epoch 00018: val_acc improved from 0.95525 to 0.95920, saving model to best_model_Ass13.h5
#  - lr: 0.50548 - momentum: 0.91
# Epoch 19/100
#  - 23s - loss: 0.1263 - acc: 0.9502 - val_loss: 0.1032 - val_acc: 0.9601
#
# Epoch 00019: val_acc improved from 0.95920 to 0.96012, saving model to best_model_Ass13.h5
#  - lr: 0.52746 - momentum: 0.91
# Epoch 20/100
#  - 23s - loss: 0.1248 - acc: 0.9507 - val_loss: 0.1034 - val_acc: 0.9603
#
# Epoch 00020: val_acc improved from 0.96012 to 0.96032, saving model to best_model_Ass13.h5
#  - lr: 0.54944 - momentum: 0.91
# Epoch 21/100
#  - 23s - loss: 0.1226 - acc: 0.9516 - val_loss: 0.0995 - val_acc: 0.9609
#
# Epoch 00021: val_acc improved from 0.96032 to 0.96086, saving model to best_model_Ass13.h5
#  - lr: 0.57142 - momentum: 0.90
# Epoch 22/100
#  - 23s - loss: 0.1207 - acc: 0.9521 - val_loss: 0.1011 - val_acc: 0.9611
#
# Epoch 00022: val_acc improved from 0.96086 to 0.96113, saving model to best_model_Ass13.h5
#  - lr: 0.59340 - momentum: 0.90
# Epoch 23/100
#  - 23s - loss: 0.1184 - acc: 0.9534 - val_loss: 0.0998 - val_acc: 0.9623
#
# Epoch 00023: val_acc improved from 0.96113 to 0.96227, saving model to best_model_Ass13.h5
#  - lr: 0.61538 - momentum: 0.90
# Epoch 24/100
#  - 23s - loss: 0.1171 - acc: 0.9539 - val_loss: 0.0996 - val_acc: 0.9620
#
# Epoch 00024: val_acc did not improve from 0.96227
#  - lr: 0.63736 - momentum: 0.90
# Epoch 25/100
#  - 24s - loss: 0.1153 - acc: 0.9544 - val_loss: 0.1021 - val_acc: 0.9605
#
# Epoch 00025: val_acc did not improve from 0.96227
#  - lr: 0.65934 - momentum: 0.89
# Epoch 26/100
#  - 23s - loss: 0.1134 - acc: 0.9555 - val_loss: 0.1030 - val_acc: 0.9613
#
# Epoch 00026: val_acc did not improve from 0.96227
#  - lr: 0.68132 - momentum: 0.89
# Epoch 27/100
#  - 24s - loss: 0.1138 - acc: 0.9552 - val_loss: 0.0975 - val_acc: 0.9626
#
# Epoch 00027: val_acc improved from 0.96227 to 0.96257, saving model to best_model_Ass13.h5
#  - lr: 0.70330 - momentum: 0.89
# Epoch 28/100
#  - 24s - loss: 0.1117 - acc: 0.9559 - val_loss: 0.0949 - val_acc: 0.9644
#
# Epoch 00028: val_acc improved from 0.96257 to 0.96441, saving model to best_model_Ass13.h5
#  - lr: 0.72528 - momentum: 0.89
# Epoch 29/100
#  - 24s - loss: 0.1104 - acc: 0.9565 - val_loss: 0.0947 - val_acc: 0.9639
#
# Epoch 00029: val_acc did not improve from 0.96441
#  - lr: 0.74726 - momentum: 0.89
# Epoch 30/100
#  - 23s - loss: 0.1097 - acc: 0.9569 - val_loss: 0.0983 - val_acc: 0.9629
#
# Epoch 00030: val_acc did not improve from 0.96441
#  - lr: 0.76924 - momentum: 0.88
# Epoch 31/100
#  - 24s - loss: 0.1067 - acc: 0.9577 - val_loss: 0.0944 - val_acc: 0.9646
#
# Epoch 00031: val_acc improved from 0.96441 to 0.96458, saving model to best_model_Ass13.h5
#  - lr: 0.79122 - momentum: 0.88
# Epoch 32/100
#  - 24s - loss: 0.1069 - acc: 0.9579 - val_loss: 0.0946 - val_acc: 0.9638
#
# Epoch 00032: val_acc did not improve from 0.96458
#  - lr: 0.81320 - momentum: 0.88
# Epoch 33/100
#  - 23s - loss: 0.1057 - acc: 0.9584 - val_loss: 0.0929 - val_acc: 0.9645
#
# Epoch 00033: val_acc did not improve from 0.96458
#  - lr: 0.83518 - momentum: 0.88
# Epoch 34/100
#  - 23s - loss: 0.1034 - acc: 0.9590 - val_loss: 0.0989 - val_acc: 0.9625
#
# Epoch 00034: val_acc did not improve from 0.96458
#  - lr: 0.85716 - momentum: 0.87
# Epoch 35/100
#  - 24s - loss: 0.1025 - acc: 0.9597 - val_loss: 0.0938 - val_acc: 0.9645
#
# Epoch 00035: val_acc did not improve from 0.96458
#  - lr: 0.87914 - momentum: 0.87
# Epoch 36/100
#  - 23s - loss: 0.1010 - acc: 0.9603 - val_loss: 0.0942 - val_acc: 0.9643
#
# Epoch 00036: val_acc did not improve from 0.96458
#  - lr: 0.90112 - momentum: 0.87
# Epoch 37/100
#  - 23s - loss: 0.1005 - acc: 0.9604 - val_loss: 0.0915 - val_acc: 0.9664
#
# Epoch 00037: val_acc improved from 0.96458 to 0.96641, saving model to best_model_Ass13.h5
#  - lr: 0.92310 - momentum: 0.87
# Epoch 38/100
#  - 24s - loss: 0.0995 - acc: 0.9608 - val_loss: 0.0887 - val_acc: 0.9667
#
# Epoch 00038: val_acc improved from 0.96641 to 0.96667, saving model to best_model_Ass13.h5
#  - lr: 0.94508 - momentum: 0.87
# Epoch 39/100
#  - 23s - loss: 0.0982 - acc: 0.9615 - val_loss: 0.0912 - val_acc: 0.9661
#
# Epoch 00039: val_acc did not improve from 0.96667
#  - lr: 0.96706 - momentum: 0.86
# Epoch 40/100
#  - 23s - loss: 0.0981 - acc: 0.9614 - val_loss: 0.0900 - val_acc: 0.9662
#
# Epoch 00040: val_acc did not improve from 0.96667
#  - lr: 0.98904 - momentum: 0.86
# Epoch 41/100
#  - 24s - loss: 0.0970 - acc: 0.9617 - val_loss: 0.0900 - val_acc: 0.9667
#
# Epoch 00041: val_acc did not improve from 0.96667
#  - lr: 1.01102 - momentum: 0.86
# Epoch 42/100
#  - 24s - loss: 0.0962 - acc: 0.9620 - val_loss: 0.0896 - val_acc: 0.9663
#
# Epoch 00042: val_acc did not improve from 0.96667
#  - lr: 1.03300 - momentum: 0.86
# Epoch 43/100
#  - 23s - loss: 0.0952 - acc: 0.9625 - val_loss: 0.0892 - val_acc: 0.9667
#
# Epoch 00043: val_acc did not improve from 0.96667
#  - lr: 1.05498 - momentum: 0.85
# Epoch 44/100
#  - 23s - loss: 0.0939 - acc: 0.9631 - val_loss: 0.0893 - val_acc: 0.9663
#
# Epoch 00044: val_acc did not improve from 0.96667
#  - lr: 1.07696 - momentum: 0.85
# Epoch 45/100
#  - 23s - loss: 0.0929 - acc: 0.9632 - val_loss: 0.0890 - val_acc: 0.9676
#
# Epoch 00045: val_acc improved from 0.96667 to 0.96762, saving model to best_model_Ass13.h5
#  - lr: 1.09894 - momentum: 0.85
# Epoch 46/100
#  - 24s - loss: 0.0926 - acc: 0.9635 - val_loss: 0.0955 - val_acc: 0.9649
#
# Epoch 00046: val_acc did not improve from 0.96762
#  - lr: 1.07708 - momentum: 0.85
# Epoch 47/100
#  - 23s - loss: 0.0914 - acc: 0.9642 - val_loss: 0.0915 - val_acc: 0.9665
#
# Epoch 00047: val_acc did not improve from 0.96762
#  - lr: 1.05510 - momentum: 0.85
# Epoch 48/100
#  - 23s - loss: 0.0903 - acc: 0.9643 - val_loss: 0.0886 - val_acc: 0.9678
#
# Epoch 00048: val_acc improved from 0.96762 to 0.96778, saving model to best_model_Ass13.h5
#  - lr: 1.03312 - momentum: 0.86
# Epoch 49/100
#  - 23s - loss: 0.0900 - acc: 0.9645 - val_loss: 0.0901 - val_acc: 0.9671
#
# Epoch 00049: val_acc did not improve from 0.96778
#  - lr: 1.01114 - momentum: 0.86
# Epoch 50/100
#  - 23s - loss: 0.0890 - acc: 0.9653 - val_loss: 0.0874 - val_acc: 0.9685
#
# Epoch 00050: val_acc improved from 0.96778 to 0.96855, saving model to best_model_Ass13.h5
#  - lr: 0.98916 - momentum: 0.86
# Epoch 51/100
#  - 23s - loss: 0.0877 - acc: 0.9656 - val_loss: 0.0869 - val_acc: 0.9673
#
# Epoch 00051: val_acc did not improve from 0.96855
#  - lr: 0.96718 - momentum: 0.86
# Epoch 52/100
#  - 23s - loss: 0.0861 - acc: 0.9658 - val_loss: 0.0873 - val_acc: 0.9681
#
# Epoch 00052: val_acc did not improve from 0.96855
#  - lr: 0.94520 - momentum: 0.87
# Epoch 53/100
#  - 23s - loss: 0.0856 - acc: 0.9661 - val_loss: 0.0917 - val_acc: 0.9670
#
# Epoch 00053: val_acc did not improve from 0.96855
#  - lr: 0.92322 - momentum: 0.87
# Epoch 54/100
#  - 24s - loss: 0.0852 - acc: 0.9665 - val_loss: 0.0872 - val_acc: 0.9683
#
# Epoch 00054: val_acc did not improve from 0.96855
#  - lr: 0.90124 - momentum: 0.87
# Epoch 55/100
#  - 23s - loss: 0.0842 - acc: 0.9668 - val_loss: 0.0903 - val_acc: 0.9674
#
# Epoch 00055: val_acc did not improve from 0.96855
#  - lr: 0.87926 - momentum: 0.87
# Epoch 56/100
#  - 23s - loss: 0.0830 - acc: 0.9674 - val_loss: 0.0893 - val_acc: 0.9682
#
# Epoch 00056: val_acc did not improve from 0.96855
#  - lr: 0.85728 - momentum: 0.87
# Epoch 57/100
#  - 23s - loss: 0.0824 - acc: 0.9675 - val_loss: 0.0894 - val_acc: 0.9680
#
# Epoch 00057: val_acc did not improve from 0.96855
#  - lr: 0.83530 - momentum: 0.88
# Epoch 58/100
#  - 23s - loss: 0.0815 - acc: 0.9680 - val_loss: 0.0875 - val_acc: 0.9684
#
# Epoch 00058: val_acc did not improve from 0.96855
#  - lr: 0.81332 - momentum: 0.88
# Epoch 59/100
#  - 24s - loss: 0.0809 - acc: 0.9683 - val_loss: 0.0884 - val_acc: 0.9675
#
# Epoch 00059: val_acc did not improve from 0.96855
#  - lr: 0.79134 - momentum: 0.88
# Epoch 60/100
#  - 23s - loss: 0.0800 - acc: 0.9687 - val_loss: 0.0869 - val_acc: 0.9690
#
# Epoch 00060: val_acc improved from 0.96855 to 0.96905, saving model to best_model_Ass13.h5
#  - lr: 0.76936 - momentum: 0.88
# Epoch 61/100
#  - 23s - loss: 0.0798 - acc: 0.9687 - val_loss: 0.0897 - val_acc: 0.9673
#
# Epoch 00061: val_acc did not improve from 0.96905
#  - lr: 0.74738 - momentum: 0.89
# Epoch 62/100
#  - 23s - loss: 0.0788 - acc: 0.9691 - val_loss: 0.0913 - val_acc: 0.9669
#
# Epoch 00062: val_acc did not improve from 0.96905
#  - lr: 0.72540 - momentum: 0.89
# Epoch 63/100
#  - 23s - loss: 0.0784 - acc: 0.9693 - val_loss: 0.0857 - val_acc: 0.9693
#
# Epoch 00063: val_acc improved from 0.96905 to 0.96925, saving model to best_model_Ass13.h5
#  - lr: 0.70342 - momentum: 0.89
# Epoch 64/100
#  - 23s - loss: 0.0776 - acc: 0.9696 - val_loss: 0.0884 - val_acc: 0.9690
#
# Epoch 00064: val_acc did not improve from 0.96925
#  - lr: 0.68144 - momentum: 0.89
# Epoch 65/100
#  - 23s - loss: 0.0764 - acc: 0.9700 - val_loss: 0.0870 - val_acc: 0.9691
#
# Epoch 00065: val_acc did not improve from 0.96925
#  - lr: 0.65946 - momentum: 0.89
# Epoch 66/100
#  - 23s - loss: 0.0761 - acc: 0.9702 - val_loss: 0.0886 - val_acc: 0.9685
#
# Epoch 00066: val_acc did not improve from 0.96925
#  - lr: 0.63748 - momentum: 0.90
# Epoch 67/100
#  - 23s - loss: 0.0745 - acc: 0.9708 - val_loss: 0.0877 - val_acc: 0.9685
#
# Epoch 00067: val_acc did not improve from 0.96925
#  - lr: 0.61550 - momentum: 0.90
# Epoch 68/100
#  - 24s - loss: 0.0743 - acc: 0.9711 - val_loss: 0.0856 - val_acc: 0.9698
#
# Epoch 00068: val_acc improved from 0.96925 to 0.96976, saving model to best_model_Ass13.h5
#  - lr: 0.59352 - momentum: 0.90
# Epoch 69/100
#  - 23s - loss: 0.0738 - acc: 0.9713 - val_loss: 0.0849 - val_acc: 0.9699
#
# Epoch 00069: val_acc improved from 0.96976 to 0.96994, saving model to best_model_Ass13.h5
#  - lr: 0.57154 - momentum: 0.90
# Epoch 70/100
#  - 23s - loss: 0.0726 - acc: 0.9717 - val_loss: 0.0889 - val_acc: 0.9683
#
# Epoch 00070: val_acc did not improve from 0.96994
#  - lr: 0.54956 - momentum: 0.91
# Epoch 71/100
#  - 23s - loss: 0.0722 - acc: 0.9719 - val_loss: 0.0869 - val_acc: 0.9690
#
# Epoch 00071: val_acc did not improve from 0.96994
#  - lr: 0.52758 - momentum: 0.91
# Epoch 72/100
#  - 23s - loss: 0.0720 - acc: 0.9720 - val_loss: 0.0935 - val_acc: 0.9675
#
# Epoch 00072: val_acc did not improve from 0.96994
#  - lr: 0.50560 - momentum: 0.91
# Epoch 73/100
#  - 23s - loss: 0.0714 - acc: 0.9720 - val_loss: 0.0874 - val_acc: 0.9688
#
# Epoch 00073: val_acc did not improve from 0.96994
#  - lr: 0.48362 - momentum: 0.91
# Epoch 74/100
#  - 23s - loss: 0.0699 - acc: 0.9729 - val_loss: 0.0928 - val_acc: 0.9683
#
# Epoch 00074: val_acc did not improve from 0.96994
#  - lr: 0.46164 - momentum: 0.91
# Epoch 75/100
#  - 23s - loss: 0.0693 - acc: 0.9729 - val_loss: 0.0884 - val_acc: 0.9697
#
# Epoch 00075: val_acc did not improve from 0.96994
#  - lr: 0.43966 - momentum: 0.92
# Epoch 76/100
#  - 23s - loss: 0.0697 - acc: 0.9728 - val_loss: 0.0889 - val_acc: 0.9695
#
# Epoch 00076: val_acc did not improve from 0.96994
#  - lr: 0.41768 - momentum: 0.92
# Epoch 77/100
#  - 23s - loss: 0.0680 - acc: 0.9736 - val_loss: 0.0898 - val_acc: 0.9694
#
# Epoch 00077: val_acc did not improve from 0.96994
#  - lr: 0.39570 - momentum: 0.92
# Epoch 78/100
#  - 23s - loss: 0.0676 - acc: 0.9738 - val_loss: 0.0893 - val_acc: 0.9692
#
# Epoch 00078: val_acc did not improve from 0.96994
#  - lr: 0.37372 - momentum: 0.92
# Epoch 79/100
#  - 23s - loss: 0.0664 - acc: 0.9740 - val_loss: 0.0914 - val_acc: 0.9681
#
# Epoch 00079: val_acc did not improve from 0.96994
#  - lr: 0.35174 - momentum: 0.93
# Epoch 80/100
#  - 23s - loss: 0.0661 - acc: 0.9741 - val_loss: 0.0897 - val_acc: 0.9692
#
# Epoch 00080: val_acc did not improve from 0.96994
#  - lr: 0.32976 - momentum: 0.93
# Epoch 81/100
#  - 24s - loss: 0.0657 - acc: 0.9740 - val_loss: 0.0884 - val_acc: 0.9698
#
# Epoch 00081: val_acc did not improve from 0.96994
#  - lr: 0.30778 - momentum: 0.93
# Epoch 82/100
#  - 23s - loss: 0.0649 - acc: 0.9744 - val_loss: 0.0877 - val_acc: 0.9697
#
# Epoch 00082: val_acc did not improve from 0.96994
#  - lr: 0.28580 - momentum: 0.93
# Epoch 83/100
#  - 23s - loss: 0.0635 - acc: 0.9753 - val_loss: 0.0884 - val_acc: 0.9693
#
# Epoch 00083: val_acc did not improve from 0.96994
#  - lr: 0.26382 - momentum: 0.93
# Epoch 84/100
#  - 23s - loss: 0.0632 - acc: 0.9753 - val_loss: 0.0907 - val_acc: 0.9691
#
# Epoch 00084: val_acc did not improve from 0.96994
#  - lr: 0.24184 - momentum: 0.94
# Epoch 85/100
#  - 23s - loss: 0.0617 - acc: 0.9758 - val_loss: 0.0899 - val_acc: 0.9695
#
# Epoch 00085: val_acc did not improve from 0.96994
#  - lr: 0.21986 - momentum: 0.94
# Epoch 86/100
#  - 23s - loss: 0.0623 - acc: 0.9757 - val_loss: 0.0883 - val_acc: 0.9694
#
# Epoch 00086: val_acc did not improve from 0.96994
#  - lr: 0.19788 - momentum: 0.94
# Epoch 87/100
#  - 23s - loss: 0.0604 - acc: 0.9766 - val_loss: 0.0887 - val_acc: 0.9701
#
# Epoch 00087: val_acc improved from 0.96994 to 0.97005, saving model to best_model_Ass13.h5
#  - lr: 0.17590 - momentum: 0.94
# Epoch 88/100
#  - 23s - loss: 0.0605 - acc: 0.9766 - val_loss: 0.0880 - val_acc: 0.9702
#
# Epoch 00088: val_acc improved from 0.97005 to 0.97022, saving model to best_model_Ass13.h5
#  - lr: 0.15392 - momentum: 0.95
# Epoch 89/100
#  - 24s - loss: 0.0594 - acc: 0.9768 - val_loss: 0.0894 - val_acc: 0.9696
#
# Epoch 00089: val_acc did not improve from 0.97022
#  - lr: 0.13194 - momentum: 0.95
# Epoch 90/100
#  - 24s - loss: 0.0595 - acc: 0.9769 - val_loss: 0.0902 - val_acc: 0.9699
#
# Epoch 00090: val_acc did not improve from 0.97022
#  - lr: 0.10996 - momentum: 0.95
# Epoch 91/100
#  - 23s - loss: 0.0591 - acc: 0.9770 - val_loss: 0.0889 - val_acc: 0.9700
#
# Epoch 00091: val_acc did not improve from 0.97022
#  - lr: 0.09905 - momentum: 0.95
# Epoch 92/100
#  - 23s - loss: 0.0578 - acc: 0.9776 - val_loss: 0.0890 - val_acc: 0.9704
#
# Epoch 00092: val_acc improved from 0.97022 to 0.97037, saving model to best_model_Ass13.h5
#  - lr: 0.08817 - momentum: 0.95
# Epoch 93/100
#  - 23s - loss: 0.0584 - acc: 0.9774 - val_loss: 0.0894 - val_acc: 0.9701
#
# Epoch 00093: val_acc did not improve from 0.97037
#  - lr: 0.07729 - momentum: 0.95
# Epoch 94/100
#  - 24s - loss: 0.0572 - acc: 0.9778 - val_loss: 0.0887 - val_acc: 0.9708
#
# Epoch 00094: val_acc improved from 0.97037 to 0.97085, saving model to best_model_Ass13.h5
#  - lr: 0.06641 - momentum: 0.95
# Epoch 95/100
#  - 23s - loss: 0.0570 - acc: 0.9780 - val_loss: 0.0878 - val_acc: 0.9704
#
# Epoch 00095: val_acc did not improve from 0.97085
#  - lr: 0.05553 - momentum: 0.95
# Epoch 96/100
#  - 23s - loss: 0.0558 - acc: 0.9782 - val_loss: 0.0897 - val_acc: 0.9701
#
# Epoch 00096: val_acc did not improve from 0.97085
#  - lr: 0.04465 - momentum: 0.95
# Epoch 97/100
#  - 24s - loss: 0.0557 - acc: 0.9783 - val_loss: 0.0897 - val_acc: 0.9704
#
# Epoch 00097: val_acc did not improve from 0.97085
#  - lr: 0.03377 - momentum: 0.95
# Epoch 98/100
#  - 23s - loss: 0.0552 - acc: 0.9786 - val_loss: 0.0898 - val_acc: 0.9706
#
# Epoch 00098: val_acc did not improve from 0.97085
#  - lr: 0.02289 - momentum: 0.95
# Epoch 99/100
#  - 23s - loss: 0.0557 - acc: 0.9785 - val_loss: 0.0881 - val_acc: 0.9707
#
# Epoch 00099: val_acc did not improve from 0.97085
#  - lr: 0.01201 - momentum: 0.95
# Epoch 100/100
#  - 23s - loss: 0.0554 - acc: 0.9783 - val_loss: 0.0896 - val_acc: 0.9702
#
# Epoch 00100: val_acc did not improve from 0.97085
#  - lr: 0.00113 - momentum: 0.95
# Model took 2366.75 seconds to train

# %% [markdown]
# # Summary:
#
# **ResNet18** network is implemented and initially trained to run for 100 epochs and validation accuracy of **95.97%** was achieved.
#
# Using LR finder the best learning rate for this network was found to be _1.099_.
# Using this as the starting LR, the network was rerun this time using OneCycleLR and an improved validation accuracy of **97.08%** is achieved.
#
# Thank you!
