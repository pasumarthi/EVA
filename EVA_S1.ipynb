# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFC8796550>

# %%
edges = cv2.Canny(image,100,200)

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x364 at 0x7EFFBFBC4390>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,0,1],[-1,0,1],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC49B0>

# %% [markdown]
# Blur Edge kernel
# Blurred images generally smooth at the corner rather edges are not easily visible. That means the image is uniformly distributed. In mathematically terms normally distributed. Filter values should be as near as possible to see the blurring effect. In short blurring the way I understand is smooth edges.

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[1,2,1],[2,4,2],[1,2,1]])/16

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC49B0>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[1,1,1],[1,1,1],[1,1,1]])/18

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC4DD8>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,1],[-1,1,0],[1,1,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC44A8>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,1],[-1,1,-1],[1,1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBD2048>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,4],[-1,4,-1],[1,4,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBD30B8>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,4],[-1,4,-1],[4,0,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBD6240>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,2],[-1,2,-1],[2,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBD8240>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,2.5],[-1,2.5,-1],[2.5,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBD8278>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,1],[-1,1,-1],[1,1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)

# %% [markdown]
# Sharpen

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,0,-1],[2,4,2],[-1,0,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC49E8>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,0,-1],[2,4,2],[-1,0,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,-1],[2,8,2],[-1,0,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC48D0>

# %%
kernel = np.float32([[-1,0,-1],[2,6,2],[-1,0,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC4E10>

# %%
kernel = np.float32([[-1,-1,-1],[1,3,1],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC4A20>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[0,-1,0],[-1,5,-1],[0,-1,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC4BE0>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[1,0,0],[0,1,0],[0,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC4E10>

# %% [markdown]
# Identity

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[0,0,0],[0,1,0],[0,0,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFFBFBC4BE0>
